# %%
import requests
import bs4 as BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
options = Options()
options.page_load_strategy = 'normal'
driver = webdriver.Chrome(options=options)

# %%
# %store -r pw
password=pw

# %%
driver.get('https://www.facebook.com/trawelloHealthyKID/posts/187159509408949?__xts__[0]=68.ARB5f3wkE6UTgwZ1NBMQm-2Ew9aTvfwj9l0MFtVUyhMsY4CQ1PIqWdNSJB40Wx9DfcR5aLol5wJLZCRXu-KzLMLx4H80O6La-243-F4o-CDXQ6tmzaQQHDgeUWjANULgEzfUnj8ZwHVwGCL9_JjIN5Xx1khcO8FE2DErLuADKBXS_edIMLWRcpBruCssful3AKgp0fIwzSa8XvhsuyhTnPPiJJYkMN2eCyborSY2Bg_r1DgQDFNl3aaVCcCUwJevM-oKZwAorO1iOBrqY07T8irdFU4KCCxJOpi3wkBW95a95j-E9gp6YtxABa1zGZRn0F3zm1yF-z9biPU5M-24VtE&__tn__=-R')

# %%
# %store -r pw
username=driver.find_element_by_xpath('//*[@id="email"]')
username.send_keys('suganros52@gmail.com')
pw=driver.find_element_by_xpath('//*[@id="pass"]')
pw.send_keys(password)
driver.find_element_by_xpath('//*[@id="u_0_2"]').click()

# %%
driver.find_element_by_xpath('//*[@id="mount_0_0"]/div/div/div[1]/div[3]/div/div/div[1]/div/div[4]/div[1]/div/div/div/div/div/div/div/div/div[1]/div/div[2]/div/div[4]/div/div/div[2]/div[2]/div/div/span').click()
driver.find_element_by_xpath('//*[@id="mount_0_0"]/div/div/div[1]/div[3]/div/div/div[2]/div/div/div[1]/div[1]/div/div/div[1]/div/div/div[1]/div[3]').click()

# %%
from bs4 import BeautifulSoup
import requests as re
import numpy as np

# %%
for i in range(1,9,1):
    driver.find_element_by_xpath('//*[@id="mount_0_0"]/div/div/div[1]/div[3]/div/div/div[1]/div/div[4]/div[1]/div/div/div/div/div/div/div/div/div[1]/div/div[2]/div/div[4]/div/div/div[2]/div[4]/div/div[2]/span/span').click()
    time.sleep(5)

# %%
a=driver.current_url
res=re.get(a)
content=driver.page_source
soup=BeautifulSoup(content,'lxml')
all_box=soup.findAll('div',{'class':'tw6a2znq sj5x9vvc d1544ag0 cxgpxx05'})
names=[]
comment=[]
no_of_comment=[]
for box in all_box:
    nm=box.find('span',{'class':'oi732d6d ik7dh3pa d2edcug0 qv66sw1b c1et5uql a8c37x1j hop8lmos enqfppq2 e9vueds3 j5wam9gi lrazzd5p oo9gr5id'})
    names.append(nm.text)
    com=box.find('div',{'style':'text-align: start;'})
    comment.append(com)

# %%
for box in all_box:
    nm=box.find('span',{'class':'oi732d6d ik7dh3pa d2edcug0 qv66sw1b c1et5uql a8c37x1j hop8lmos enqfppq2 e9vueds3 j5wam9gi lrazzd5p oo9gr5id'})
    names.append(nm.text)
    com=box.find('div',{'style':'text-align: start;'})
    comment.append(com)

# %%
import pandas as pd
dic={'Name':names,'Comments':comment}
sol1=pd.DataFrame(dic)
#sol.to_csv(r'C:\Users\Roshan\Desktop\quotes.csv')

# %%
sol1
# Out:
#                      Name                                           Comments
# 0      Healthy Kids India  [Parents, online voting is going to be closed ...
# 1           Râñjîth Smárt                        [[#M11],  and , [#MC33], .]
# 2          Arpita Awasthi  [Drawing by#M10 name Aradhya Panday is  my fav...
# 3         Saravanan Mohan  [Great job & well done Shwetha. Both were real...
# 4            Mamta Sharma  [Drawing by , [#MC38], , , [#MC39],  & , [#MC40]]
# ..                    ...                                                ...
# 354         Shweta Sharma                         [# Mc38,Mc39Mct40 is good]
# 355      Varsha Agnihotri                         [Best drawings for me are]
# 356       Nandeeshiah B M  [Best drawing for me are , [#M6], ,, [#MC11], ...
# 357  Bhargava Sreenivasan                                       [[#MC],  16]
# 358        Sunita Chauhan                  [[#MC41],  , [#MC42],  , [#MC43]]
#
# [359 rows x 2 columns]

# %%
sol1['Com']=sol1['Comments'].apply(lambda x:r.findall('MC\d\d',str(x)))

# %%
sol1['Com']
# Out:
# 0                      []
# 1                  [MC33]
# 2                      []
# 3                  [MC33]
# 4      [MC38, MC39, MC40]
#               ...
# 354                    []
# 355                    []
# 356          [MC11, MC10]
# 357                    []
# 358    [MC41, MC42, MC43]
# Name: Com, Length: 359, dtype: object

# %%
sol1.head(25)
# Out:
#                        Name  \
# 0        Healthy Kids India
# 1             Râñjîth Smárt
# 2            Arpita Awasthi
# 3           Saravanan Mohan
# 4              Mamta Sharma
# 5          Nibedita Acharya
# 6                Sakthi Vel
# 7    Jayatirtha Periyapatna
# 8     Sivanesan Palanichamy
# 9              Anaaya Singh
# 10           Shèkhãr Kìççhã
# 11           Saurabh Shukla
# 12           Akshara Sriram
# 13          Priyanka Kumari
# 14             Harjeet Kaur
# 15      Kaleeswaran Sampath
# 16             Archana Venu
# 17          Shraddha Sharma
# 18           Harshit Sharma
# 19      Pramod Kumar Sharma
# 20             Rahul Saxena
# 21             Rajesh Kumar
# 22  Selvakumar Palaniyappan
# 23             Manju Sharma
# 24   Muralikrishna Nidugala
#
#                                              Comments                 Com
# 0   [Parents, online voting is going to be closed ...                  []
# 1                         [[#M11],  and , [#MC33], .]              [MC33]
# 2   [Drawing by#M10 name Aradhya Panday is  my fav...                  []
# 3   [Great job & well done Shwetha. Both were real...              [MC33]
# 4   [Drawing by , [#MC38], , , [#MC39],  & , [#MC40]]  [MC38, MC39, MC40]
# 5      [Best Drawings for me are : M2, MC15 and MC50]        [MC15, MC50]
# 6   [Well done Shwetha. , [#M11],  and , [#MC33], ...              [MC33]
# 7     [Excellent , [#MC16],  ,, [#MC33], , , [#MC61]]  [MC16, MC33, MC61]
# 8   [[#M11],  and , [#MC33],  are so beautiful and...              [MC33]
# 9   [Best drawings for me are#MC41,, [#MC42], ,, [...  [MC41, MC42, MC43]
# 10                  [M6,MC9 and M6 are best drawings]                  []
# 11  [ Keep it up Agrima Singh , [#MC41], ,, [#MC42...  [MC41, MC42, MC43]
# 12  [My vote is for , [#MC16], . The drawing is ve...              [MC16]
# 13  [[#MC41],  , [#MC42],  , [#MC43],  the best dr...  [MC41, MC42, MC43]
# 14                  [[#MC38],  , [#MC39],  , [#MC40]]  [MC38, MC39, MC40]
# 15  [Superb Shwetha.  , [#M11],  and , [#MC33], .....              [MC33]
# 16  [Good job kids.. , [#MC16], , , [#MC70],  and ...  [MC16, MC70, MC61]
# 17       [[#MC38],  , [#MC39],  , [#MC40],  are good]  [MC38, MC39, MC40]
# 18       [[#MC38],  , [#MC39],  , [#MC40],  are good]  [MC38, MC39, MC40]
# 19  [Well done , [#MC38], , , [#MC39],  & , [#MC40...  [MC38, MC39, MC40]
# 20  [[#MC38],  , [#MC39],  , [#MC40],  NICELY DONE...  [MC38, MC39, MC40]
# 21  [ , [#M11],  and , [#MC33],  are wonderful dra...              [MC33]
# 22  [[#M11],  and , [#MC33],  is best drawing for ...              [MC33]
# 23       [[#MC38],  , [#MC39],  , [#MC40],  are good]  [MC38, MC39, MC40]
# 24  [My vote: , [#M8], , , [#MC71], , , [#MC20], ,...  [MC71, MC20, MC72]
